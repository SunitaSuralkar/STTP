# %% [markdown]
# <a href="https://colab.research.google.com/github/SunitaSuralkar/STTP/blob/main/Copy_of_Lab1_Introduction_to_Pyspark_Functional_Programming_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %% [markdown]
# ## LAB1 :**To understand functional programming concepts in Spark using RDD transformations and actions.**
#
# **Concepts Used**
#
# map()
#
# filter()
#
# reduce()

# %%
from pyspark import SparkContext

sc = SparkContext("local", "FunctionalProgrammingLab")

# %%
# Create RDD
numbers = sc.parallelize([1, 2, 3, 4, 5, 6])

# %%
# Functional transformations
cube_roots = numbers.map(lambda x: x ** (1.0/3.0))
even_numbers = numbers.filter(lambda x: x % 2 == 0)

# %%
# Action
sum_result = numbers.reduce(lambda a, b: a + b)

# %%
print("Cube Roots:", [round(v,4) for v in cube_roots.collect()])
print("Even Numbers:", even_numbers.collect())
print("Sum:", sum_result)

sc.stop()
